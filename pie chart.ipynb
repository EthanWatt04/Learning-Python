# %% [markdown]
# # TEST

# %%
from matplotlib import pyplot as plt

#plt.style.use("ggplot")

slices = [30, 40, 15, 5, 10]
labels = ["Football", "Rugby", "Hockey", "Tennis", "Golf"]

plt.pie(slices, labels=labels, wedgeprops={"edgecolor": "white"})

plt.title("My First Pie Chart")

plt.show()

# %% [markdown]
# # TEST.2

# %%
from matplotlib import pyplot as plt

slices = [59219, 55466, 47544, 36443, 35917, 31991, 27097, 23030,
          20524, 18523, 18017, 7920, 7331, 7201, 5833]
labels = ['JavaScript', 'HTML/CSS', 'SQL', 'Python', 'Java', 'Bash/Shell/PowerShell',
          'C#', 'PHP', 'C++', 'TypeScript', 'C', 'Other(s):', 'Ruby', 'Go', 'Assembly']

plt.pie(slices, labels=labels, wedgeprops={"edgecolor": "white"})

plt.title("Most Popular Programing Languages")

plt.show()

# %% [markdown]
# # TEST.3

# %%
from matplotlib import pyplot as plt

plt.style.use("ggplot")

slices = [59219, 55466, 47544, 36443, 35917]
labels = ['JavaScript', 'HTML/CSS', 'SQL', 'Python', 'Java']
explode = [0, 0, 0, 0, 0]

plt.pie(slices, labels=labels, explode=explode, shadow=True, startangle=0, autopct="%1.1f%%", wedgeprops={"edgecolor": "white"})

plt.title("Most Popular Programing Languages")



plt.show()
